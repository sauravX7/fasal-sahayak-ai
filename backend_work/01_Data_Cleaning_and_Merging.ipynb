# %%
import pandas as pd

base_df = pd.read_csv(r'C:\Users\ankad\Documents\SIH_Work\fasal-sahayak-ai\odisha_weather_crop_data.csv')

# %%
# Rename all columns to snake_case for consistency
base_df.columns = base_df.columns.str.lower().str.replace(' ', '_')

# Specifically check and rename any that the above missed
base_df = base_df.rename(columns={
    'avg_temp': 'avg_temp_c',
    'total_precipitation': 'total_precip_mm'
})

# Ensure all column names are standardized
print("Standardized Column Names:")
print(base_df.columns)
# Out:
# Standardized Column Names:
# Index(['state', 'district', 'crop', 'year', 'season', 'area', 'area_units',
#        'production', 'production_units', 'yield', 'avg_temp_c',
#        'total_precip_mm'],
#       dtype='object')

# %%
print("\n--- Final Base Data Info ---")
base_df.info()

print("\n--- Final Base Data Head ---")
print(base_df.head())

print("\n--- Final Base Data Null Check ---")
print(base_df.isnull().sum())

# Save this as our official "version 1" base data
base_df.to_csv('base_data_v1.csv', index=False)
# Out:
# --- Final Base Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16153 entries, 0 to 16152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             16153 non-null  object
#  1   district          16153 non-null  object
#  2   crop              16153 non-null  object
#  3   year              16153 non-null  object
#  4   season            16153 non-null  object
#  5   area              16153 non-null  float64
#  6   area_units        16153 non-null  object
#  7   production        16101 non-null  float64
#  8   production_units  16153 non-null  object
#  9   yield             16153 non-null  float64
#  10  avg_temp_c        16153 non-null  float64
#  11  total_precip_mm   16153 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 1.5+ MB
#
# --- Final Base Data Head ---
#     state  district       crop     year  season     area area_units  \
# ...
